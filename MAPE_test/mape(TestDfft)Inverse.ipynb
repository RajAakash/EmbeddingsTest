# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers


# ----------------------------
# 1️ Reproducibility
# ----------------------------
def set_global_seed(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    print(f"🌱 Global random seed set to {seed}")


# ----------------------------
# 2️ Model Definition
# ----------------------------
def build_model(input_dim, learning_rate=0.0005):
    model = Sequential([
        Dense(256, activation='relu', input_shape=(input_dim,),
              kernel_regularizer=regularizers.l2(1e-4)),
        Dropout(0.2),

        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
        Dropout(0.2),

        Dense(64, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
        Dense(1, activation='linear')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='mse',
                  metrics=['mape'])
    return model


# ----------------------------
# 3️ Training Function
# ----------------------------
def train_nn_regressor(train_csv, test_csv=None, target_column="target",
                       use_split=False, seed=42):
    set_global_seed(seed)

    # --- Load data ---
    df_train = pd.read_csv(train_csv)
    if test_csv:
        df_test = pd.read_csv(test_csv)
    elif use_split:
        df_train, df_test = train_test_split(df_train, test_size=0.2, random_state=seed)
    else:
        raise ValueError("Either provide a test CSV or set use_split=True.")

    # --- Fill NaNs ---
    df_train = df_train.fillna(df_train.mean(numeric_only=True))
    df_test = df_test.fillna(df_test.mean(numeric_only=True))

    # --- Split X and y ---
    X_train = df_train.drop(columns=[target_column]).values
    y_train = df_train[target_column].values.reshape(-1, 1)
    X_test = df_test.drop(columns=[target_column]).values
    y_test = df_test[target_column].values.reshape(-1, 1)

    # --- Scale features ---
    scaler_X = StandardScaler()
    X_train = scaler_X.fit_transform(X_train)
    X_test = scaler_X.transform(X_test)

    # --- Scale target (-1, 1) ---
    scaler_y = MinMaxScaler(feature_range=(-1, 1))
    y_train_scaled = scaler_y.fit_transform(y_train)
    y_test_scaled = scaler_y.transform(y_test)

    # --- Build model ---
    model = build_model(X_train.shape[1], learning_rate=0.0005)

    # --- Callbacks ---
    early_stop = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

    # --- Train ---
    history = model.fit(
        X_train, y_train_scaled,
        validation_data=(X_test, y_test_scaled),
        epochs=800,
        batch_size=32,
        verbose=1,
        callbacks=[early_stop, reduce_lr]
    )

    # --- Predict & inverse-transform ---
    y_pred_scaled = model.predict(X_test).reshape(-1, 1)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)
    y_test_original = scaler_y.inverse_transform(y_test_scaled)

    # --- Metrics ---
    mape = mean_absolute_percentage_error(y_test_original, y_pred) * 100
    mae = mean_absolute_error(y_test_original, y_pred)
    r2 = r2_score(y_test_original, y_pred)

    print(f"\n Final Test MAPE: {mape:.3f}%")
    print(f" Mean Absolute Error (MAE): {mae:.5f}")
    print(f" R² Score: {r2:.4f}")

    # --- Visualization ---
    plot_results(y_test_original, y_pred)

    return model, history, (mape, mae, r2), (y_test_original, y_pred)


# ----------------------------
# 4️ Visualization
# ----------------------------
def plot_results(y_true, y_pred):
    # --- Predicted vs Actual ---
    plt.figure(figsize=(6, 6))
    plt.scatter(y_true, y_pred, alpha=0.6)
    min_val, max_val = min(y_true.min(), y_pred.min()), max(y_true.max(), y_pred.max())
    plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')
    plt.title("Predicted vs Actual Values")
    plt.xlabel("Actual (True Values)")
    plt.ylabel("Predicted Values")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # --- Residual Plot ---
    residuals = y_true - y_pred
    plt.figure(figsize=(6, 4))
    plt.scatter(y_true, residuals, alpha=0.6)
    plt.axhline(0, color='r', linestyle='--')
    plt.title("Residuals vs True Values")
    plt.xlabel("Actual (True Values)")
    plt.ylabel("Residual (y_true - y_pred)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()


# ----------------------------
# 5️ Example Usage
# ----------------------------
model, history, metrics, (y_true, y_pred) = train_nn_regressor(
    # train_csv="output_quartz(ruby)_TestDfft.csv",
    # test_csv="/g/g90/dhakal1/All/MIN_example/generated_cycles(TestDfft)/generated_cycle_1.csv",
    test_csv="output_quartz(ruby)_TestDfft.csv",
    train_csv="/g/g90/dhakal1/All/MIN_example/generated_cycles(TestDfft)/generated_cycle_1.csv",
    target_column="relative_runtime",
    seed=42
)
# Out:
# 2025-11-07 14:34:23.855476: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762554863.875442 4192857 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762554863.881650 4192857 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-07 14:34:23.903549: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🌱 Global random seed set to 42
# Epoch 1/800
# /g/g90/dhakal1/All/dev/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-11-07 14:34:28.242111: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-11-07 14:34:28.397774: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2018 - mape: 86.7719 - val_loss: 0.3441 - val_mape: 611.1092 - learning_rate: 5.0000e-04
# Epoch 2/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0577 - mape: 39.6386 - val_loss: 0.2968 - val_mape: 812.1180 - learning_rate: 5.0000e-04
# Epoch 3/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0480 - mape: 37.3833 - val_loss: 0.2804 - val_mape: 822.4230 - learning_rate: 5.0000e-04
# Epoch 4/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0424 - mape: 29.4897 - val_loss: 0.2947 - val_mape: 825.7469 - learning_rate: 5.0000e-04
# Epoch 5/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - mape: 28.7544 - val_loss: 0.2789 - val_mape: 840.4821 - learning_rate: 5.0000e-04
# Epoch 6/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0395 - mape: 25.3302 - val_loss: 0.3007 - val_mape: 846.4330 - learning_rate: 5.0000e-04
# Epoch 7/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0381 - mape: 24.5123 - val_loss: 0.3122 - val_mape: 930.8430 - learning_rate: 5.0000e-04
# Epoch 8/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0343 - mape: 21.3787 - val_loss: 0.3172 - val_mape: 906.0697 - learning_rate: 5.0000e-04
# Epoch 9/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0338 - mape: 23.6898 - val_loss: 0.3081 - val_mape: 942.2360 - learning_rate: 5.0000e-04
# Epoch 10/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0340 - mape: 24.5986 - val_loss: 0.3002 - val_mape: 881.3680 - learning_rate: 5.0000e-04
# Epoch 11/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0322 - mape: 18.5190 - val_loss: 0.3014 - val_mape: 866.6854 - learning_rate: 5.0000e-04
# Epoch 12/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0318 - mape: 19.7207 - val_loss: 0.3025 - val_mape: 912.9169 - learning_rate: 5.0000e-04
# Epoch 13/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0304 - mape: 17.3087 - val_loss: 0.3187 - val_mape: 903.0843 - learning_rate: 5.0000e-04
# Epoch 14/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0293 - mape: 19.3935 - val_loss: 0.3125 - val_mape: 928.4868 - learning_rate: 5.0000e-04
# Epoch 15/800
#  3/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0296 - mape: 22.5479
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0293 - mape: 19.4980 - val_loss: 0.3204 - val_mape: 925.2476 - learning_rate: 5.0000e-04
# Epoch 16/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0287 - mape: 18.0021 - val_loss: 0.3176 - val_mape: 909.3977 - learning_rate: 2.5000e-04
# Epoch 17/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0279 - mape: 14.8072 - val_loss: 0.3182 - val_mape: 916.7230 - learning_rate: 2.5000e-04
# Epoch 18/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0270 - mape: 14.9349 - val_loss: 0.3152 - val_mape: 938.3479 - learning_rate: 2.5000e-04
# Epoch 19/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0272 - mape: 16.0163 - val_loss: 0.3213 - val_mape: 934.8419 - learning_rate: 2.5000e-04
# Epoch 20/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0265 - mape: 14.3689 - val_loss: 0.3190 - val_mape: 922.4125 - learning_rate: 2.5000e-04
# Epoch 21/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0271 - mape: 15.5613 - val_loss: 0.3144 - val_mape: 910.6873 - learning_rate: 2.5000e-04
# Epoch 22/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0263 - mape: 14.0258 - val_loss: 0.3060 - val_mape: 886.9647 - learning_rate: 2.5000e-04
# Epoch 23/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0256 - mape: 15.6813 - val_loss: 0.3133 - val_mape: 920.1895 - learning_rate: 2.5000e-04
# Epoch 24/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0258 - mape: 16.1465 - val_loss: 0.3167 - val_mape: 916.3004 - learning_rate: 2.5000e-04
# Epoch 25/800
#  2/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - mape: 8.5764
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0253 - mape: 13.4005 - val_loss: 0.3304 - val_mape: 932.3199 - learning_rate: 2.5000e-04
# Epoch 26/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255 - mape: 14.1644 - val_loss: 0.3174 - val_mape: 942.1187 - learning_rate: 1.2500e-04
# Epoch 27/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - mape: 13.9363 - val_loss: 0.3166 - val_mape: 929.5366 - learning_rate: 1.2500e-04
# Epoch 28/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0240 - mape: 11.9889 - val_loss: 0.3191 - val_mape: 921.6629 - learning_rate: 1.2500e-04
# Epoch 29/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0247 - mape: 14.0812 - val_loss: 0.3188 - val_mape: 930.7719 - learning_rate: 1.2500e-04
# Epoch 30/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - mape: 11.9471 - val_loss: 0.3200 - val_mape: 923.2850 - learning_rate: 1.2500e-04
# Epoch 31/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - mape: 13.6613 - val_loss: 0.3175 - val_mape: 911.7084 - learning_rate: 1.2500e-04
# Epoch 32/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240 - mape: 14.1736 - val_loss: 0.3226 - val_mape: 915.6830 - learning_rate: 1.2500e-04
# Epoch 33/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241 - mape: 11.9202 - val_loss: 0.3263 - val_mape: 934.9601 - learning_rate: 1.2500e-04
# Epoch 34/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - mape: 12.2192 - val_loss: 0.3235 - val_mape: 940.8364 - learning_rate: 1.2500e-04
# Epoch 35/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - mape: 12.7391
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237 - mape: 12.8524 - val_loss: 0.3173 - val_mape: 918.2786 - learning_rate: 1.2500e-04
# Epoch 36/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - mape: 12.0487 - val_loss: 0.3197 - val_mape: 905.4277 - learning_rate: 6.2500e-05
# Epoch 37/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0234 - mape: 11.9753 - val_loss: 0.3200 - val_mape: 906.9431 - learning_rate: 6.2500e-05
# Epoch 38/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - mape: 12.1162 - val_loss: 0.3160 - val_mape: 890.9928 - learning_rate: 6.2500e-05
# Epoch 39/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0233 - mape: 12.9322 - val_loss: 0.3147 - val_mape: 892.4756 - learning_rate: 6.2500e-05
# Epoch 40/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - mape: 12.5678 - val_loss: 0.3188 - val_mape: 906.1570 - learning_rate: 6.2500e-05
# Epoch 41/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - mape: 12.0495 - val_loss: 0.3161 - val_mape: 889.2594 - learning_rate: 6.2500e-05
# Epoch 42/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - mape: 14.6513 - val_loss: 0.3150 - val_mape: 899.5098 - learning_rate: 6.2500e-05
# Epoch 43/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0229 - mape: 14.4312 - val_loss: 0.3126 - val_mape: 894.0604 - learning_rate: 6.2500e-05
# Epoch 44/800
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - mape: 11.6607 - val_loss: 0.3163 - val_mape: 909.9257 - learning_rate: 6.2500e-05
# Epoch 45/800
#  2/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - mape: 8.2864
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0227 - mape: 10.6742 - val_loss: 0.3089 - val_mape: 891.4522 - learning_rate: 6.2500e-05
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
#  Final Test MAPE: 15.410%
#  Mean Absolute Error (MAE): 0.16749
#  R² Score: -0.2181
# 2025-11-07 14:34:34.513117: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
